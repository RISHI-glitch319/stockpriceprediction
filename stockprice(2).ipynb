# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading csv file
data = pd.read_csv("VTI.csv")

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-09-01  225.339996  225.779999  223.960007  224.679993  221.337479
# 1  2023-09-05  224.259995  224.639999  223.279999  223.339996  220.017441
# 2  2023-09-06  222.990005  223.179993  220.750000  221.940002  218.638275
# 3  2023-09-07  220.380005  221.500000  220.080002  221.179993  217.889572
# 4  2023-09-08  221.210007  222.179993  220.979996  221.419998  218.125992
#
#     Volume
# 0  3047300
# 1  2531500
# 2  2473700
# 3  2964700
# 4  2244400

# %%
#assigning the data to variables
x = data.drop(['Date','Adj Close','Close'],axis = True)
y = data['Close']

# %%
x
# Out:
#            Open        High         Low   Volume
# 0    225.339996  225.779999  223.960007  3047300
# 1    224.259995  224.639999  223.279999  2531500
# 2    222.990005  223.179993  220.750000  2473700
# 3    220.380005  221.500000  220.080002  2964700
# 4    221.210007  222.179993  220.979996  2244400
# ..          ...         ...         ...      ...
# 246  278.130005  278.529999  276.260010  2263800
# 247  276.100006  277.380005  275.609985  1787900
# 248  276.799988  277.079987  273.920013  1856400
# 249  276.480011  278.309998  275.239990  3018000
# 250  276.720001  278.529999  275.079987  2028200
#
# [251 rows x 4 columns]

# %%
#importing train test split method
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Pair plots for all the data
sns.pairplot(data)

# %%
#Visulizing the Training plots
plt.plot(x_train,y_train,'r.',label='train_data')
plt.xlabel('x_train')
plt.ylabel('y_train')
plt.legend()
plt.show()

# %%
#Visualizing the Tesing plots
plt.plot(x_test,y_test,'g.',label='test_data')
plt.xlabel('x_test')
plt.ylabel('y_test')
plt.legend()
plt.show()

# %%
#import linear regression algorithm
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#predict the values and assigning
y_predict = regressor.predict(x_test).round(1)

# %%
calculation = pd.DataFrame(np.c_[y_test, y_predict], columns=['Actual', 'Predicted'])
calculation
# Out:
#         Actual  Predicted
# 0   249.139999      249.5
# 1   221.729996      222.5
# 2   252.770004      252.2
# 3   225.229996      225.6
# 4   247.860001      246.9
# 5   259.989990      260.3
# 6   268.720001      268.3
# 7   275.450012      274.8
# 8   221.029999      221.5
# 9   251.830002      251.4
# 10  259.450012      259.4
# 11  279.100006      278.9
# 12  272.760010      272.8
# 13  258.500000      259.1
# 14  227.759995      227.8
# 15  269.690002      270.1
# 16  266.769989      267.4
# 17  214.500000      214.1
# 18  251.240005      252.0
# 19  212.960007      211.8
# 20  275.750000      274.8
# 21  212.410004      212.6
# 22  248.460007      249.1
# 23  228.850006      228.8
# 24  261.929993      262.8
# 25  215.500000      215.2
# 26  224.789993      224.7
# 27  221.050003      221.5
# 28  216.009995      216.1
# 29  261.790009      260.1
# 30  267.119995      266.4
# 31  211.080002      212.0
# 32  271.059998      271.6
# 33  266.890015      266.4
# ...

# %%
#importing r**2 Square method in linear Regression
from sklearn.metrics import r2_score

# %%
#checking r**2 square of Linear Regression
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9975591384511546

# %%
#Checking the accuracy of train and testing of  Linear Regression
print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9995931024409888
# Testing Accuracy : 0.9975398311875228

# %%
#importing Random Forest Regressor algorithm
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
#predicting the values with random forest
y_pred=model.predict(x_test).round(1)

# %%
#Dataframe design for predicted values
calculation = pd.DataFrame(np.c_[y_test, y_pred], columns=['Actual', 'Predicted'])
calculation
# Out:
#         Actual  Predicted
# 0   249.139999      249.6
# 1   221.729996      222.4
# 2   252.770004      252.7
# 3   225.229996      225.1
# 4   247.860001      247.1
# 5   259.989990      261.5
# 6   268.720001      267.1
# 7   275.450012      275.1
# 8   221.029999      222.2
# 9   251.830002      249.9
# 10  259.450012      258.9
# 11  279.100006      276.7
# 12  272.760010      274.2
# 13  258.500000      259.1
# 14  227.759995      226.7
# 15  269.690002      269.3
# 16  266.769989      267.7
# 17  214.500000      213.2
# 18  251.240005      252.4
# 19  212.960007      211.2
# 20  275.750000      274.1
# 21  212.410004      213.1
# 22  248.460007      249.5
# 23  228.850006      228.2
# 24  261.929993      262.9
# 25  215.500000      215.9
# 26  224.789993      223.8
# 27  221.050003      221.3
# 28  216.009995      215.9
# 29  261.790009      259.6
# 30  267.119995      265.8
# 31  211.080002      212.8
# 32  271.059998      272.7
# 33  266.890015      267.1
# ...

# %%
from sklearn.metrics import r2_score

# %%
#checking r**2 square of Random Forest
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9975501828242505

# %%
#Checking the accuracy of train and testing of Random Forest
print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9995872527827523
# Testing Accuracy : 0.9975870628808954
